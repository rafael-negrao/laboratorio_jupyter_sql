# %% [markdown]
# # Instalar o PostgreSQL

# %%
# !apt-get update
# !apt-get install postgresql postgresql-contrib -y

# %% [markdown]
# # Inciar o Serviço do PostgreSQL

# %%
# !service postgresql start

# %% [markdown]
# # Configurar um Usuário e Banco de Teste

# %%
# !su - postgres -c "psql -c \"CREATE USER colab_user WITH PASSWORD 'colab_pass';\""
# !su - postgres -c "psql -c \"CREATE DATABASE colab_db OWNER colab_user;\""

# %% [markdown]
# # Instalar o driver de conexão e plugins

# %%
# !pip install ipython-sql
# !pip install psycopg2-binary
# !pip install JupySQL

# %% [markdown]
# # Carregando extensão para SQL

# %%
# %load_ext sql

# %%
# %sql postgresql://colab_user:colab_pass@localhost/colab_db

# %% [markdown]
# # Testando a conexão

# %% [markdown]
# ## Cria tabela teste

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS cliente
# (
#     id          SERIAL PRIMARY KEY,
#     nome        VARCHAR(100)       NOT NULL,
#     cpf         VARCHAR(11) UNIQUE NOT NULL,
#     telefone    VARCHAR(15),
#     email       VARCHAR(100),
#     logradouro  VARCHAR(100),
#     numero      VARCHAR(10),
#     complemento VARCHAR(50),
#     bairro      VARCHAR(50),
#     cidade      VARCHAR(50),
#     estado      VARCHAR(2),
#     cep         VARCHAR(8)
# );

# %% [markdown]
# ## Carregando dados teste

# %%
# %%sql
# INSERT INTO cliente (nome, cpf, telefone, email, logradouro, numero, complemento, bairro, cidade, estado, cep) VALUES
# ('Carlos', '28322004745', '1159621767', 'carlos1@example.com', 'Rua Dez', '8', 'Apto 2', 'Bairro Oito', 'Cidade Quatro', 'PE', '49072328'),
# ('Gabriel', '83523357751', '1137863065', 'gabriel2@example.com', 'Rua Dois', '34', 'Apto 8', 'Bairro Nove', 'Cidade Dois', 'BA', '87149582'),
# ('Julia', '70060502951', '1152398801', 'julia3@example.com', 'Rua Dez', '84', 'Apto 1', 'Bairro Oito', 'Cidade Nove', 'SC', '65430999'),
# ('Daniela', '60747571647', '1103614175', 'daniela4@example.com', 'Rua Nove', '47', 'Apto 5', 'Bairro Quatro', 'Cidade Seis', 'SC', '35854219'),
# ('Igor', '35879455642', '1135382098', 'igor5@example.com', 'Rua Nove', '93', 'Apto 11', 'Bairro Nove', 'Cidade Oito', 'CE', '02757308'),
# ('Eduardo', '76035526983', '1144368943', 'eduardo6@example.com', 'Rua Um', '37', 'Apto 18', 'Bairro Três', 'Cidade Dois', 'SC', '20226228'),
# ('Bruno', '43019928404', '1178961311', 'bruno7@example.com', 'Rua Dez', '58', 'Apto 2', 'Bairro Seis', 'Cidade Cinco', 'MG', '12219890'),
# ('Carlos', '55921539864', '1136380026', 'carlos8@example.com', 'Rua Dez', '48', 'Apto 10', 'Bairro Dois', 'Cidade Cinco', 'CE', '78063781'),
# ('Carlos', '84674425200', '1154736843', 'carlos9@example.com', 'Rua Três', '92', 'Apto 11', 'Bairro Cinco', 'Cidade Seis', 'SC', '09069863'),
# ('Gabriel', '45500435497', '1196319536', 'gabriel10@example.com', 'Rua Dez', '61', 'Apto 17', 'Bairro Nove', 'Cidade Quatro', 'BA', '19489343'),
# ('Carlos', '34296986823', '1162114481', 'carlos11@example.com', 'Rua Quatro', '7', 'Apto 6', 'Bairro Dez', 'Cidade Sete', 'SC', '76541103'),
# ('Julia', '88587222853', '1163634066', 'julia12@example.com', 'Rua Sete', '22', 'Apto 3', 'Bairro Dois', 'Cidade Dez', 'RJ', '01439156'),
# ('Carlos', '38631440383', '1132895900', 'carlos991@example.com', 'Rua Três', '40', 'Apto 15', 'Bairro Seis', 'Cidade Dez', 'MG', '52018454'),
# ('Fernanda', '70024297318', '1143829546', 'fernanda992@example.com', 'Rua Dois', '46', 'Apto 13', 'Bairro Cinco', 'Cidade Sete', 'BA', '88109027'),
# ('Bruno', '69655754830', '1186258948', 'bruno993@example.com', 'Rua Cinco', '84', 'Apto 6', 'Bairro Nove', 'Cidade Dois', 'RJ', '11701435'),
# ('Bruno', '23616978590', '1128317719', 'bruno994@example.com', 'Rua Seis', '61', 'Apto 11', 'Bairro Um', 'Cidade Nove', 'SC', '47291799'),
# ('Fernanda', '77900904818', '1103275461', 'fernanda995@example.com', 'Rua Quatro', '48', 'Apto 10', 'Bairro Um', 'Cidade Três', 'MG', '70342231'),
# ('Fernanda', '11094747568', '1194016863', 'fernanda996@example.com', 'Rua Oito', '75', 'Apto 4', 'Bairro Dois', 'Cidade Sete', 'BA', '13785260'),
# ('Ana', '13581366280', '1100317732', 'ana997@example.com', 'Rua Três', '43', 'Apto 12', 'Bairro Nove', 'Cidade Nove', 'ES', '49512293'),
# ('Bruno', '28159126008', '1183481509', 'bruno998@example.com', 'Rua Oito', '51', 'Apto 12', 'Bairro Um', 'Cidade Três', 'SC', '20877273'),
# ('Igor', '73160779389', '1102519082', 'igor999@example.com', 'Rua Sete', '7', 'Apto 15', 'Bairro Quatro', 'Cidade Três', 'PR', '25732528'),
# ('Julia', '57967553183', '1190954338', 'julia1000@example.com', 'Rua Nove', '76', 'Apto 19', 'Bairro Dois', 'Cidade Oito', 'PE', '27960882');

# %%
# %%sql
# select * from cliente

# %% [markdown]
# ## Removendo tabela

# %%
# %%sql
# DROP TABLE cliente

# %% [markdown]
# # Fechando a conexão com o banco de dados

# %%
# %sql --close postgresql://colab_user:***@localhost/colab_db

# %% [markdown]
# `[INFO]: FIM DO NOTEBOOK`
