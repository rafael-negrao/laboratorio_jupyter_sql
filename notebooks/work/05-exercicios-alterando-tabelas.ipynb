# %% [markdown]
# # Exercício 3: Alterando Tabelas
#
# ## Abrindo conexão com o banco de dados

# %%
# %load_ext sql
# %sql postgresql://admin:admin@postgres-sql-aula:5432/curso_sql

# %% [markdown]
# ## Adicionar uma coluna status à tabela pedido

# %%
# %%sql
# ALTER TABLE pedido ADD COLUMN status VARCHAR(10) NOT NULL DEFAULT 'ativo';

# %% [markdown]
# > O comando abaixo é especifíco para o banco de dados PostgreSQL

# %%
# %%sql
# -- no mysql
# -- show create table pedido
# -- no postgre
# SELECT
#     a.attnum AS numero,
#     a.attname AS coluna,
#     format_type(a.atttypid, a.atttypmod) AS tipo,
#     NOT a.attnotnull AS is_nullable,
#     pg_get_expr(ad.adbin, ad.adrelid) AS default_value
# FROM pg_attribute a
# LEFT JOIN pg_attrdef ad
#        ON a.attrelid = ad.adrelid AND a.attnum = ad.adnum
# WHERE a.attrelid = 'pedido'::regclass
#   AND a.attnum > 0
#   AND NOT a.attisdropped
# ORDER BY a.attnum;

# %% [markdown]
# ## Modificar a tabela item_pedido para incluir desconto

# %%
# %%sql
# ALTER TABLE item_pedido ADD COLUMN desconto DECIMAL(10, 2) DEFAULT 0;

# %% [markdown]
# > O comando abaixo é especifíco para o banco de dados PostgreSQL

# %%
# %%sql
# -- no postgre
# SELECT
#     a.attnum AS numero,
#     a.attname AS coluna,
#     format_type(a.atttypid, a.atttypmod) AS tipo,
#     NOT a.attnotnull AS is_nullable,
#     pg_get_expr(ad.adbin, ad.adrelid) AS default_value
# FROM pg_attribute a
# LEFT JOIN pg_attrdef ad
#        ON a.attrelid = ad.adrelid AND a.attnum = ad.adnum
# WHERE a.attrelid = 'item_pedido'::regclass
#   AND a.attnum > 0
#   AND NOT a.attisdropped
# ORDER BY a.attnum;

# %% [markdown]
# ### Fechar a conexão com o banco de dados

# %%
# Fechar a conexão com o banco de dados
# %sql --close postgresql://admin:***@postgres-sql-aula:5432/curso_sql

# %% [markdown]
# ## Navegação
# - [Anterior](04-exercicios-criar-indices.ipynb)
# - [Próximo](06-select-tipos-de-joins.ipynb)

# %% [markdown]
# `[INFO]: FIM NOTEBOOK`
