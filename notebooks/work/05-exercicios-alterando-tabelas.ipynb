# %% [markdown]
# # Exercício 3: Alterando Tabelas
#
# ## Abrindo conexão com o banco de dados

# %%
# %load_ext sql
# %sql postgresql://admin:admin@postgres-sql-aula:5432/curso_sql

# %% [markdown]
# ## Adicionar uma coluna status à tabela pedido

# %%
# %%sql
# ALTER TABLE pedido ADD COLUMN status VARCHAR(10) NOT NULL DEFAULT 'ativo';

# %% [markdown]
# ## Modificar a tabela item_pedido para incluir desconto

# %%
# %%sql
# ALTER TABLE item_pedido ADD COLUMN desconto DECIMAL(10, 2) DEFAULT 0;

# %% [markdown]
# ### Fechar a conexão com o banco de dados

# %%
# Fechar a conexão com o banco de dados
# %sql --close postgresql://admin:***@postgres-sql-aula:5432/curso_sql

# %% [markdown]
# ## Navegação
# - [Anterior](04-exercicios-criar-indices.ipynb)
# - [Próximo](06-exercicios-criar-view.ipynb)

# %% [markdown]
# `[INFO]: FIM NOTEBOOK`
