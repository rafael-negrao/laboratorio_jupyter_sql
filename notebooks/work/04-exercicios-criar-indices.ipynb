# %% [markdown]
# # Exercício 2: Criação de Índices
#
# ## Abrindo conexão com o banco de dados

# %%
# %load_ext sql
# %sql postgresql://admin:admin@postgres-sql-aula:5432/curso_sql

# %% [markdown]
# ## Adicionar um índice ao campo email da tabela cliente

# %%
# %%sql
# CREATE INDEX idx_email ON cliente(email);

# %% [markdown]
# ## Adicionar um índice ao campo nome da tabela produto

# %%
# %%sql
# CREATE INDEX idx_nome_produto ON produto(nome);

# %% [markdown]
# ### Fechar a conexão com o banco de dados

# %%
# Fechar a conexão com o banco de dados
# %sql --close postgresql://admin:***@postgres-sql-aula:5432/curso_sql

# %% [markdown]
# ## Navegação
# - [Anterior](03-exercicios-criar-tabela.ipynb)
# - [Próximo](05-exercicios-alterando-tabelas.ipynb)

# %% [markdown]
# `[INFO]: FIM NOTEBOOK`
