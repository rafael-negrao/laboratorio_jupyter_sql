# %% [markdown]
# # Exercício 1: Criação de Tabelas
#
# ## Modelo de entidade de relacionamento - MER
# ![mer-v1.0.0.png](https://github.com/rafael-negrao/laboratorio_jupyter_sql/blob/main/notebooks/imagens%2Fmer-v1.0.0.png?raw=1)

# %% [markdown]
# ### Abrindo conexão com o banco de dados

# %%
# %load_ext sql

# %%
#%sql postgresql://[user]:[password]@[host]/[database]?sslmode=require
# %sql postgresql://admin:admin@postgres-sql-aula:5432/curso_sql
# Out:
# Connecting to 'postgresql://admin:***@postgres-sql-aula:5432/curso_sql'

# %% [markdown]
# ### Removendo as tabelas

# %%
# %%sql
# DROP VIEW IF EXISTS v_detalhe_pedido_cliente CASCADE;
# DROP TABLE IF EXISTS item_pedido CASCADE;
# DROP TABLE IF EXISTS entrega CASCADE;
# DROP TABLE IF EXISTS pedido CASCADE;
# DROP TABLE IF EXISTS produto_categoria CASCADE;
# DROP TABLE IF EXISTS produto CASCADE;
# DROP TABLE IF EXISTS categoria CASCADE;
# DROP TABLE IF EXISTS cliente CASCADE;
# DROP TABLE IF EXISTS forma_pagamento CASCADE;
# DROP TABLE IF EXISTS transportadora CASCADE;
# Out:
# Running query in 'postgresql://retool:***@ep-nameless-art-af21n0t2.c-2.us-west-2.retooldb.com/retool?sslmode=require'
# ++
# ||
# ++
# ++

# %% [markdown]
# ### Criar a tabela cliente

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS cliente
# (
#     id          SERIAL PRIMARY KEY,
#     nome        VARCHAR(100)       NOT NULL,
#     cpf         VARCHAR(11) UNIQUE NOT NULL,
#     telefone    VARCHAR(15),
#     email       VARCHAR(100),
#     logradouro  VARCHAR(100),
#     numero      VARCHAR(10),
#     complemento VARCHAR(50),
#     bairro      VARCHAR(50),
#     cidade      VARCHAR(50),
#     estado      VARCHAR(2),
#     cep         VARCHAR(8)
# );
# Out:
# Running query in 'postgresql://retool:***@ep-nameless-art-af21n0t2.c-2.us-west-2.retooldb.com/retool?sslmode=require'
# ++
# ||
# ++
# ++

# %% [markdown]
# ### Criar a tabela produto

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS produto
# (
#     id    SERIAL PRIMARY KEY,
#     nome  VARCHAR(100)   NOT NULL,
#     preco DECIMAL(10, 2) NOT NULL CHECK (preco >= 0)
# );
# Out:
# Running query in 'postgresql://retool:***@ep-nameless-art-af21n0t2.c-2.us-west-2.retooldb.com/retool?sslmode=require'
# ++
# ||
# ++
# ++

# %% [markdown]
# ### Criar a tabela categoria

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS categoria
# (
#     id        SERIAL PRIMARY KEY,
#     nome      VARCHAR(100) NOT NULL,
#     descricao TEXT
# );
# Out:
# Running query in 'postgresql://retool:***@ep-nameless-art-af21n0t2.c-2.us-west-2.retooldb.com/retool?sslmode=require'
# ++
# ||
# ++
# ++

# %% [markdown]
# ### Criar a tabela de associaçao produto categoria

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS produto_categoria
# (
#     produto_id   INT NOT NULL,
#     categoria_id INT NOT NULL,
#     PRIMARY KEY (produto_id, categoria_id),
#     FOREIGN KEY (produto_id) REFERENCES produto (id) ON DELETE CASCADE,
#     FOREIGN KEY (categoria_id) REFERENCES categoria (id) ON DELETE CASCADE
# );
# Out:
# Running query in 'postgresql://retool:***@ep-nameless-art-af21n0t2.c-2.us-west-2.retooldb.com/retool?sslmode=require'
# ++
# ||
# ++
# ++

# %% [markdown]
# ### Criar a tabela Pedido

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS pedido
# (
#     id          SERIAL PRIMARY KEY,
#     cliente_id  INT  NOT NULL,
#     data_pedido DATE NOT NULL,
#     FOREIGN KEY (cliente_id) REFERENCES cliente (id) ON DELETE CASCADE
# );
# Out:
# Running query in 'postgresql://retool:***@ep-nameless-art-af21n0t2.c-2.us-west-2.retooldb.com/retool?sslmode=require'
# ++
# ||
# ++
# ++

# %% [markdown]
# ### Criar a tabela item_pedido (associação entre Pedido e Produto)

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS item_pedido
# (
#     pedido_id      INT            NOT NULL,
#     produto_id     INT            NOT NULL,
#     quantidade     INT            NOT NULL CHECK (quantidade > 0),
#     preco_unitario DECIMAL(10, 2) NOT NULL,
#     PRIMARY KEY (pedido_id, produto_id),
#     FOREIGN KEY (pedido_id) REFERENCES pedido (id) ON DELETE CASCADE,
#     FOREIGN KEY (produto_id) REFERENCES produto (id) ON DELETE CASCADE
# );
# Out:
# Running query in 'postgresql://retool:***@ep-nameless-art-af21n0t2.c-2.us-west-2.retooldb.com/retool?sslmode=require'
# ++
# ||
# ++
# ++

# %% [markdown]
# ### Fechar a conexão com o banco de dados

# %%
# Fechar a conexão com o banco de dados
# %sql --close postgresql://admin:***@postgres-sql-aula:5432/curso_sql
# %sql --close postgresql://[user]:***@[host]/[database]

# %% [markdown]
# ## Navegação
# - [Anterior](02-introducao-sql.ipynb)
# - [Próximo](04-exercicios-criar-indices.ipynb)
