# %% [markdown]
# # Aula de SQL
#
# Experimento 2

# %% [markdown]
# ## Abrindo conexão com o banco de dados

# %%
# %load_ext sql
# %sql mysql+pymysql://user_app:user_app@db_lab_mysql:3306/db_lab_mysql
# Out:
# Connecting to 'mysql+pymysql://user_app:***@db_lab_mysql:3306/db_lab_mysql'

# %% [markdown]
# ## Fazendo teste de conexão de dado de dados

# %%
# %%sql
# SELECT
#   1
# Out:
# Running query in 'mysql+pymysql://user_app:***@db_lab_mysql:3306/db_lab_mysql'
# 1 rows affected.
# +---+
# | 1 |
# +---+
# | 1 |
# +---+

# %% [markdown]
# ## Executando o script

# %%
# %sql --file UserTable.sql
# Out:
# Running query in 'mysql+pymysql://user_app:***@db_lab_mysql:3306/db_lab_mysql'
# 3 rows affected.
# ++
# ||
# ++
# ++

# %% [markdown]
# ## Recuperando os dados

# %%
# %%sql
#
# select * from usuarios
# Out:
# Running query in 'mysql+pymysql://user_app:***@db_lab_mysql:3306/db_lab_mysql'
# 3 rows affected.
# +----+----------------+-----------------+-------+
# | id |      nome      |      email      | idade |
# +----+----------------+-----------------+-------+
# | 1  |   João Silva   |  joao@email.com |   30  |
# | 2  |  Maria Santos  | maria@email.com |   25  |
# | 3  | Pedro Oliveira | pedro@email.com |   35  |
# +----+----------------+-----------------+-------+
